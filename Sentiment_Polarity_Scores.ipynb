# %%
import findspark
findspark.init("/home/vbhamidipati1/spark")
from pyspark import SparkContext
from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import lit
from textblob import TextBlob

# %%
spark = SparkSession \
        .builder \
        .appName("Count Number of tweets based on state") \
        .getOrCreate()

# %%
# Read the CSV as a pandas dataframe here
commentsDF = spark.read.option("delimiter", "\t").load('/home/vbhamidipati1/spark/workspace/Project_YouTube_Sentiment_Analysis/Data/preprocessed_comments.csv', 
                      format='com.databricks.spark.csv', 
                      header='true', 
                      inferSchema='true').drop('_c0')

# %%
commentsDF.show()
# Out:
# +-----------+--------------------+-----+-------+
# |   video_id|        comment_text|likes|replies|
# +-----------+--------------------+-----+-------+
# |XpVt6Z1Gjjo|          logan paul|    4|      0|
# |XpVt6Z1Gjjo|been following fr...|    3|      0|
# |XpVt6Z1Gjjo|       kong maverick|    3|      0|
# |XpVt6Z1Gjjo|          attendance|    3|      0|
# |XpVt6Z1Gjjo|            trending|    3|      0|
# |XpVt6Z1Gjjo|   trending ayyeeeee|    3|      0|
# |XpVt6Z1Gjjo|              though|    4|      0|
# |XpVt6Z1Gjjo|            trending|    3|      0|
# |XpVt6Z1Gjjo|happy year vlogav...|    3|      0|
# |XpVt6Z1Gjjo|your shit brother...|    0|      0|
# |XpVt6Z1Gjjo|there should mini...|    0|      0|
# |XpVt6Z1Gjjo|dear logan really...|    0|      0|
# |XpVt6Z1Gjjo|honestly evan ann...|    0|      0|
# |XpVt6Z1Gjjo|casey still bette...|    0|      0|
# |XpVt6Z1Gjjo|geez rick this fa...|    0|      0|
# |XpVt6Z1Gjjo|   happy cause movie|    0|      0|
# |XpVt6Z1Gjjo|ayyyyoooo logang ...|    1|      0|
# |XpVt6Z1Gjjo|didnt give merch ...|    0|      0|
# |XpVt6Z1Gjjo|been watching gro...|    3|      0|
# |XpVt6Z1Gjjo|made people hate ...|    0|      0|
# +-----------+--------------------+-----+-------+
# only showing top 20 rows

# %%
comments_with_polarity = commentsDF.withColumn("pol", lit(0))
comments_with_polarity.show()
# Out:
# +-----------+--------------------+-----+-------+---+
# |   video_id|        comment_text|likes|replies|pol|
# +-----------+--------------------+-----+-------+---+
# |XpVt6Z1Gjjo|          logan paul|    4|      0|  0|
# |XpVt6Z1Gjjo|been following fr...|    3|      0|  0|
# |XpVt6Z1Gjjo|       kong maverick|    3|      0|  0|
# |XpVt6Z1Gjjo|          attendance|    3|      0|  0|
# |XpVt6Z1Gjjo|            trending|    3|      0|  0|
# |XpVt6Z1Gjjo|   trending ayyeeeee|    3|      0|  0|
# |XpVt6Z1Gjjo|              though|    4|      0|  0|
# |XpVt6Z1Gjjo|            trending|    3|      0|  0|
# |XpVt6Z1Gjjo|happy year vlogav...|    3|      0|  0|
# |XpVt6Z1Gjjo|your shit brother...|    0|      0|  0|
# |XpVt6Z1Gjjo|there should mini...|    0|      0|  0|
# |XpVt6Z1Gjjo|dear logan really...|    0|      0|  0|
# |XpVt6Z1Gjjo|honestly evan ann...|    0|      0|  0|
# |XpVt6Z1Gjjo|casey still bette...|    0|      0|  0|
# |XpVt6Z1Gjjo|geez rick this fa...|    0|      0|  0|
# |XpVt6Z1Gjjo|   happy cause movie|    0|      0|  0|
# |XpVt6Z1Gjjo|ayyyyoooo logang ...|    1|      0|  0|
# |XpVt6Z1Gjjo|didnt give merch ...|    0|      0|  0|
# |XpVt6Z1Gjjo|been watching gro...|    3|      0|  0|
# |XpVt6Z1Gjjo|made people hate ...|    0|      0|  0|
# +-----------+--------------------+-----+-------+---+
# only showing top 20 rows

# %%
def polarityAnalysis(video_id, comments, likes, replies, polarity):
    try:
        analysis =TextBlob(comments)
        polarity = analysis.sentiment.polarity
        if polarity < 0:
            polarity = -1
        elif polarity > 0:
            polarity = 1
        else:
            polarity = 0
    except:
        polarity = 0
    yield (video_id, comments, likes, replies, polarity)

# %%
Adjusted_polarity = comments_with_polarity.rdd.flatMap(lambda line : polarityAnalysis(line[0], line[1], line[2], line[3], line[4]))
Adjusted_polarity.persist()
# Out:
# PythonRDD[24] at RDD at PythonRDD.scala:53

# %%
Adjusted_polarity.collect()
# Out:
# [('XpVt6Z1Gjjo', 'logan paul', 4, 0, 0),
#  ('XpVt6Z1Gjjo',
#   'been following from start your vine channel have seen vlogs',
#   3,
#   0,
#   0),
#  ('XpVt6Z1Gjjo', 'kong maverick', 3, 0, 0),
#  ('XpVt6Z1Gjjo', 'attendance', 3, 0, 0),
#  ('XpVt6Z1Gjjo', 'trending', 3, 0, 0),
#  ('XpVt6Z1Gjjo', 'trending ayyeeeee', 3, 0, 0),
#  ('XpVt6Z1Gjjo', 'though', 4, 0, 0),
#  ('XpVt6Z1Gjjo', 'trending', 3, 0, 0),
#  ('XpVt6Z1Gjjo', 'happy year vlogaversary', 3, 0, 1),
#  ('XpVt6Z1Gjjo',
#   'your shit brother have single handedly ruined youtube thanks',
#   0,
#   0,
#   -1),
#  ('XpVt6Z1Gjjo', 'there should mini logan paul', 0, 0, 0),
#  ('XpVt6Z1Gjjo',
#   'dear logan really wanna your merch have money even have would really make have your merch',
#   0,
#   0,
#   1),
#  ('XpVt6Z1Gjjo',
#   'honestly evan annoying like funny watching famous trying hard like',
#   0,
#   0,
#   1),
#  ('XpVt6Z1Gjjo', 'casey still better then logan', 0, 0, 1),
#  ('XpVt6Z1Gjjo', 'geez rick this face youtube', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'happy cause movie', 0, 0, 1),
#  ('XpVt6Z1Gjjo',
#   'ayyyyoooo logang what this hard vlog watch logan dare destroyed that youtube logang army check covers share them logang help subscribers today think subscribe',
#   1,
#   0,
#   -1),
#  ('XpVt6Z1Gjjo', 'didnt give merch johannes', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'been watching grow days straight seem grow advice', 3, 0, 1),
#  ('XpVt6Z1Gjjo', 'made people hate youtube', 0, 0, -1),
#  ('XpVt6Z1Gjjo', 'honey nooo believe almost mili year damnn', 0, 0, 0),
#  ('XpVt6Z1Gjjo',
#   'jake paul fastest growing channel million thats fact dont want believe that then just away',
#   1,
#   0,
#   0),
#  ('XpVt6Z1Gjjo',
#   'pewdiepie accidentally played song with words during stream watch that part channel just uploaded like more could this',
#   0,
#   0,
#   1),
#  ('XpVt6Z1Gjjo', 'should prank that broke your play puttun', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'love logan jake much thay amazing look them much', 1, 0, 1),
#  ('XpVt6Z1Gjjo', 'trending', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'evan being such dick this vlog', 0, 0, 0),
#  ('XpVt6Z1Gjjo',
#   'allot diss likes comments lets diss like this please',
#   0,
#   0,
#   0),
#  ('XpVt6Z1Gjjo',
#   'evan horrible human being also looks jealous when open like should happy',
#   0,
#   0,
#   -1),
#  ('XpVt6Z1Gjjo',
#   'love much love meet live israel really inspire really like your channel keep doing what nbecause everyone loves will unique pashan will creative hope will',
#   0,
#   0,
#   1),
#  ('XpVt6Z1Gjjo', 'watch clicking here people entertaining', 0, 0, 1),
#  ('XpVt6Z1Gjjo', 'dying when threw midget ground lmao', 0, 0, 1),
#  ('XpVt6Z1Gjjo', 'technically logan jake started channel', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'logan life from england', 0, 0, 0),
#  ('XpVt6Z1Gjjo',
#   'gotta love youtube giving morons ability earn buck from other morons',
#   0,
#   0,
#   -1),
#  ('XpVt6Z1Gjjo',
#   'evan being douch logans getting pissed logan should have went smash game system then evan would have cried evans gonna able take care pitbull tell gonna kill kong',
#   0,
#   0,
#   1),
#  ('XpVt6Z1Gjjo',
#   'pauls please stop saying they fastest growing youtube channels that pewdiepie position made managed subscribers guys have months that hard understand',
#   1,
#   0,
#   -1),
#  ('XpVt6Z1Gjjo',
#   'trump trending youtube wait this trump sure looks like',
#   0,
#   0,
#   1),
#  ('XpVt6Z1Gjjo',
#   'when this first like naaahhhhh tired looked again title like llllllzzzz yeeeaaahhhh anniversary present logan paul gonna halloween show much changed life even joking about',
#   0,
#   0,
#   1),
#  ('XpVt6Z1Gjjo',
#   'subscribed today this only second video watched idea year special',
#   0,
#   0,
#   1),
#  ('XpVt6Z1Gjjo',
#   'jake started youtube years first years technically logan first',
#   0,
#   0,
#   1),
#  ('XpVt6Z1Gjjo', 'girl with kylie jenner', 1, 0, 0),
#  ('XpVt6Z1Gjjo', 'hater fuck', 0, 0, -1),
#  ('XpVt6Z1Gjjo', 'where other', 0, 0, -1),
#  ('XpVt6Z1Gjjo', 'dislike every single your videos', 0, 0, -1),
#  ('XpVt6Z1Gjjo',
#   'this looks like great video after done would kind enough check youtube channel give some feedback maybe even subscribing',
#   0,
#   0,
#   1),
#  ('XpVt6Z1Gjjo', 'diamond play button appraised', 0, 0, 0),
#  ('XpVt6Z1Gjjo',
#   'would what editing things your videos trying start have idea make cool edits',
#   0,
#   0,
#   1),
#  ('XpVt6Z1Gjjo', 'thumbnail threatening', 0, 0, 0),
#  ('XpVt6Z1Gjjo',
#   'talking about changed logging forever channel should more humbling somebody else made this video instead know logan paul make video about logan paul change login forever didn change shit anything just exposed large audience five year olds maybe even freshman high school that like your videos people that hook with fuck really really pathetic your entire audience made these people nobody actually afford anything without asking their parents that exactly your audience',
#   0,
#   0,
#   -1),
#  ('XpVt6Z1Gjjo', 'fuck this dude brother', 0, 0, -1),
#  ('XpVt6Z1Gjjo', 'have card board picture alya like look', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'just arrogant with title', 0, 0, 0),
#  ('XpVt6Z1Gjjo',
#   'evan just taking money granted cause said rolex fake diamonds wouldn friend anymore left when said diamond real keep commenting probably joke cause might opinion that using logan money granted',
#   0,
#   0,
#   -1),
#  ('XpVt6Z1Gjjo', 'broke play button', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'youtube spoiled hollywood brat', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'attack titan squad were', 0, 0, 0),
#  ('XpVt6Z1Gjjo',
#   'congrats logan love much someday would love meet logang',
#   0,
#   0,
#   1),
#  ('XpVt6Z1Gjjo', 'well best vlog expecting more congrats', 0, 0, 1),
#  ('XpVt6Z1Gjjo', 'evan lowkey starting piss', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'tone down didn change youtube', 0, 0, -1),
#  ('XpVt6Z1Gjjo', 'worms congrats being simple minded', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'this copy paste take over youtube', 1, 0, 0),
#  ('XpVt6Z1Gjjo',
#   'fucking cares year there comes point where whole goofy every second every schtick yeah impressing douchey year olds waste their lives youtube real world your fucktard brother nothing more than pair over privileged white privileged toddlers grow fuck think this will your life forever going face real world realize just jump around scream your real hair flip your inevitable date rape charge',
#   0,
#   0,
#   1),
#  ('XpVt6Z1Gjjo', 'best', 1, 0, 1),
#  ('XpVt6Z1Gjjo', 'well done love much', 1, 0, 1),
#  ('XpVt6Z1Gjjo',
#   'very happy this need spread more love united stand divided fall',
#   1,
#   0,
#   1),
#  ('XpVt6Z1Gjjo',
#   'friends subscribe aaaaaaaaaaaa diamond play button',
#   1,
#   0,
#   0),
#  ('XpVt6Z1Gjjo', 'like logan your brother menace youtube', 1, 0, 0),
#  ('XpVt6Z1Gjjo', 'login were march bought months', 1, 0, 0),
#  ('XpVt6Z1Gjjo', 'made this bday', 2, 0, 0),
#  ('XpVt6Z1Gjjo', 'this', 2, 0, 0),
#  ('XpVt6Z1Gjjo', 'love evan much', 2, 0, 1),
#  ('XpVt6Z1Gjjo', 'everyday', 0, 0, -1),
#  ('XpVt6Z1Gjjo', 'dafuq just watch', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'jake paul', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'subscribe channel', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'logang gang gang', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'whooooo logang', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'trending good', 0, 0, 1),
#  ('XpVt6Z1Gjjo', 'days vlogs', 1, 0, 0),
#  ('XpVt6Z1Gjjo', None, 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'balls itchy', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'logan', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'what happen mavrick', 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'this shit', 0, 0, -1),
#  ('XpVt6Z1Gjjo', 'trending', 1, 0, 0),
#  ('XpVt6Z1Gjjo', 'gote', 0, 0, 0),
#  ('XpVt6Z1Gjjo', None, 0, 0, 0),
#  ('XpVt6Z1Gjjo', 'tomorrow birthday', 2, 0, 0),
#  ('XpVt6Z1Gjjo', 'trending', 1, 0, 0),
#  ('XpVt6Z1Gjjo', 'trending fuck', 2, 0, -1),
#  ('XpVt6Z1Gjjo', 'first', 2, 0, 1),
#  ('XpVt6Z1Gjjo', 'woooooooooooooooow', 1, 0, 0),
#  ('XpVt6Z1Gjjo', 'happy vlogiversary', 2, 0, 1),
#  ('XpVt6Z1Gjjo', 'trending whoaaaa', 1, 0, 0),
#  ('XpVt6Z1Gjjo', 'boiiii trending lmao', 2, 0, 1),
#  ('XpVt6Z1Gjjo', 'treading', 2, 0, 0),
#  ('XpVt6Z1Gjjo', 'eyyyjooooo good morning loooganng whats popppinnn', 2, 0, 1),
#  ('XpVt6Z1Gjjo', 'good trending logan', 2, 0, 1),
#  ('cLdxuaxaQwc', 'love pewdiepie apologize your fine', 0, 0, 1),
#  ('cLdxuaxaQwc',
#   'seeing much idiocy lack self awareness these comments with some knowledge word okay because body counts huge amount human suffering attached word goes back slave owning days same word with hard black folks word because theirs reclaim person color that word vocabulary because black aware oppression tied this word also piss baby arguing should able such gross word because again this word mine reclaim yeah fine when these black rappers word because part their personal history grown woman still disbelief that people have pinch empathy their fellow human beings black irrelevant conversation whether word bottom line still arguing your right well then have news racist',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc',
#   'pewds behind this just another attack your character love',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc', 'telling that perfect sometimes fuck nthat wired', 0, 0, 1),
#  ('cLdxuaxaQwc',
#   'everybody says that when play call duty other games immature over looked great people takes someone fight about life',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc', 'never apologise regressives', 0, 0, 0),
#  ('cLdxuaxaQwc',
#   'dont sorry pewds everybody says something everyday your public person says this time fukin news over world talking about jeeezyys keep doing what your doing niggah',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'other streamers same thing apologize here prime example truly moral person tries hard even censors himself good example makes tiny mistake they attack example where teachers writes time tables starts writing then writes rest right kids make because wrong fail acknowledge that rest correct goes show people will quickly make your mistakes ignore your accomplishments keep doing what doing pewds truly inspiration',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'proceed with caution nthis comment section will give stage cancer immediately',
#   0,
#   0,
#   0),
#  ('cLdxuaxaQwc', 'this thing shit happens', 0, 0, -1),
#  ('cLdxuaxaQwc',
#   'forgot that pewdiepie fandom majority white people white dont tell they should feel ancestors paid that word with their blood today ever want cannot tell should feel disgusting backing your problematic fave pretty sure this before pewdiepie canceled',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'this could honestly become good thing platform where could really educate people especially when many your fans seem think okay said really learn about history word come back because could really help educate people that powerful',
#   1,
#   0,
#   1),
#  ('cLdxuaxaQwc',
#   'what hell wrong with everyone talking badly about said word accident pewdiepie super cool love people here supporting',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc',
#   'guys that word once used demeaning term that history that word will never change pewds fucked still quite obviously wasn intention word racist those people overreacting making easier toxic media influencers fuck every single content creator because they blowing this proportion pewds racist',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'pewdiepie nothing sorry about everybody need their head their over themselves maybe when black person makes offensive remark about white person should call them racist they like turn about fair play',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc',
#   'think other youtube hatting just jealous that bigger than them think wronge common give this break have heard this word said black people daily they white people sensitive indian have heard sooo much rasisum from every body including black white people this outrageous pissed happy clearly hyped time when said this actually just support understand that human well',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'famous theyre take this outta proportion keemstar idubbz didnt attacked media just because theyre smaller',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc', 'will forgive anything', 0, 0, 0),
#  ('cLdxuaxaQwc',
#   'think funny said word sudden world words hurt need grow honestly because this fact that offended word dissapointing like seriously theres much worse youtube does anything about that grow least decency what said this everyone entire world lets camara apologize infront millions people cant',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'angry shouldn have apologize such word then should using just white people support pewds',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc', 'humans make mistakes havent made them arent human', 0, 0, 0),
#  ('cLdxuaxaQwc',
#   'convinced large percentage pewdiepie audience year white boys think they edgy saying word',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc', 'racist rather accident', 0, 0, 0),
#  ('cLdxuaxaQwc',
#   'like when other people these things fine when famous person says this everyone loses their heads',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc',
#   'people because said word said accident cause everyone does',
#   0,
#   0,
#   0),
#  ('cLdxuaxaQwc', 'just word calm down', 0, 0, 1),
#  ('cLdxuaxaQwc',
#   'lets honest here guys have word slip before cmon confronted with word music shows friends cmon have slip atleast once lets front',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc',
#   'people saying that since black people does matter another race says this many reasons society shit doesn matter black says that doesn justify other groups using term shit like that doesn just slip that worst word think scary dumb people these comments work america some your reasoning validation reasoning using word ridiculous #smd',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'humble pewds didn mean cause drama that crowds create good example your fans',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc', 'watch clicking here people entertaining', 1, 0, 1),
#  ('cLdxuaxaQwc',
#   'listen listen white people judge criticize what said word said offensive slang black people anyone right offended them please people comments stop saying just word feel offended them them what they think about what happened',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc', 'what', 0, 0, 0),
#  ('cLdxuaxaQwc',
#   'honestly racist their nowadays even make jokes asian having small eyes common doesnt affect plus didnt purpose really meant would sorry',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'your black have right that word point blank period',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc',
#   'white know really offensive fuck does saying this affect didn anything about someone trying mean them need chill',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc', 'sticks stones break bones words will never hurt', 0, 0, 0),
#  ('cLdxuaxaQwc',
#   'apologize political correctness newspeak word leftist censorship these media outlets just trying bring down solely because seem somewhat right winged fucking wall street journal tried same thing months they failed lmao',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc', 'forgive blame people saying word ourselves', 0, 0, 0),
#  ('cLdxuaxaQwc', 'social justice warriors need chill', 0, 0, 1),
#  ('cLdxuaxaQwc',
#   'black american think that deal haven even seen clip from what heard from what know about pewds from watching years conclude wasn meant offensive lots time word used variants meant racist worth getting offended over although people have this weird obsession with saying while context does matter regardless word with shitty history unnecessary when people have fixation with word weirds makes think they closet racists people think edgy something talking primarily about nigger nigga because that word totally different connotation',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'saying nigga even only hateful black people babies immature people stop going guarantee youse wouldn idubbz others because pewdiepie think have right full force were people coming from because pewdiepie start biggest crisis platform ever much pressure that speech down like idubbz just example',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc', 'word alright people overreacting waaaaay much', 0, 0, 1),
#  ('cLdxuaxaQwc',
#   'idubbbz says niggerfaggot like every single video year hilarious everyone such boner love felix',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc',
#   'really sorry donate money africa that from making this video',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'poods irrespective your intentions which genuinely believe pure hateful public face voice what influences others greatly really disappointing that still struggle really respect influence have youtube your million audience hope wake fuck stop this shit because good entertaining really should better than this hope turn things around more woke',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc', 'okay', 0, 0, 1),
#  ('cLdxuaxaQwc',
#   'weird thumbs doesn stay could corrupted youtube again',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'nobody cares about word loses power over people tell that only saying this because understand people have been slaughtered before countries have been defiled enslaved used prostitutes only feel like guys letting this word still enslave',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc', 'gives shit', 0, 0, -1),
#  ('cLdxuaxaQwc',
#   'there people suffering from hurricanes allz worried about some cracka with potty mouth nsincerely your friendly neighborhood beaner',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc',
#   'honestly care word overpower always will care about pewdie',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc',
#   'word cracker journos wont care because theres huge double standard they hate white people',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'this face screams gonna kill myself seems have lost zest life',
#   0,
#   0,
#   0),
#  ('cLdxuaxaQwc',
#   'blacks folks that shit with every sentence when whitey says accident without disrespectful thoughts whole world turns',
#   0,
#   0,
#   0),
#  ('cLdxuaxaQwc', 'felix', 0, 0, 0),
#  ('cLdxuaxaQwc',
#   'think okay sorry about that done strange that have here kind people which this word with nothing happen other people where everybody insane just think',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'power disease care cure keep caring yourself others best this life',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc', 'likes pickle', 0, 0, 0),
#  ('cLdxuaxaQwc', 'many sorrys still able part youtube', 0, 0, 1),
#  ('cLdxuaxaQwc', 'real life racism world says shit video game', 0, 0, -1),
#  ('cLdxuaxaQwc',
#   'people coments stupid adult mastake should know stop defending time',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc', 'stupid', 0, 0, -1),
#  ('cLdxuaxaQwc',
#   'only people getting triggered saying word actually black',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'felix care context what matters know racist feed into these stupid narratives',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'felix newly subscriber didn your apologizing your channel heard douchebag sargon akkad mentioned channel where clearly stating that more then that particular word racist actually said multiple times clarly have more integrity higher moral character then albanien swed verry proud apologizing brah',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc',
#   'said some hateful shit while playing video games tend rage that rage probably shouldn have said some stuff that idgaf',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'defended pewds last racist thing pewds racist that just inappropriate dark humor there need sensitive accidentally racist several occasions accident actually racist never ever said word because from white person that terribly hurtful word with black family members that have would never want young cousins hear word that came this mans mouth especially since influencer going hearing more then hear well pewdiepie said okay something heat moment only slips frequently think gotta give defending this been subscribed like years time farewell',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'pewdiepie puts sorry video saying word comments people typing',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'basically face youtube someone woken from coma since before youtube around first thing they know about youtube know have this pressure under your shoulders because anything wrong would like youtube logo walked stage said fuck hard control speak know feel didn have apologize said nigger yellow fucking blob',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'these people that saying should what ever want also trump supporters',
#   0,
#   0,
#   0),
#  ('cLdxuaxaQwc', 'pewd have anything apologize just word', 0, 0, 0),
#  ('cLdxuaxaQwc', 'thank apologizing pewds haven lost respect', 0, 0, 0),
#  ('cLdxuaxaQwc', 'happens carry', 0, 0, 0),
#  ('cLdxuaxaQwc',
#   'dude just word maybe shouldn getting butt hurt honest',
#   0,
#   0,
#   1),
#  ('cLdxuaxaQwc', 'like said voldemort evil wizards gonna come word', 0, 0, -1),
#  ('cLdxuaxaQwc', 'just word', 0, 0, 0),
#  ('cLdxuaxaQwc',
#   'black american says word called slang black american call white people typical white girls called white person says word racist',
#   0,
#   0,
#   -1),
#  ('cLdxuaxaQwc',
#   'people give power word they want hear someone says word slide because making bigger deal stop caring things will cool',
#   1,
#   0,
#   1),
#  ('cLdxuaxaQwc', 'everyone makes mistakes', 0, 0, 0),
#  ('cLdxuaxaQwc', 'nice kaws statues dude', 0, 0, 1),
#  ('cLdxuaxaQwc', 'fuck niggers', 0, 0, -1),
#  ('cLdxuaxaQwc', 'https youtu xbjtnahvlag', 0, 0, 0),
#  ('cLdxuaxaQwc',
#   'food thought everybody https youtube watch izlofcxx',
#   0,
#   0,
#   0),
#  ('cLdxuaxaQwc', 'adams', 0, 0, 0),
#  ('cLdxuaxaQwc', 'damn nigga', 0, 0, 0),
#  ('cLdxuaxaQwc', 'nigge whut', 1, 0, 0),
#  ('cLdxuaxaQwc', 'niggers', 0, 0, 0),
#  ('cLdxuaxaQwc', 'nigga', 0, 0, 0),
#  ('cLdxuaxaQwc', 'pussy', 0, 0, 0),
#  ('cLdxuaxaQwc', '#deletethischannel', 0, 0, 0),
#  ('cLdxuaxaQwc', 'pewdiepie bumass nigga lmao', 0, 0, 1),
#  ('cLdxuaxaQwc', 'nigga', 0, 0, 0),
#  ('cLdxuaxaQwc', 'okay pewds', 0, 0, 1),
#  ('cLdxuaxaQwc', 'fucking nigger', 0, 0, -1),
#  ('cLdxuaxaQwc', 'love felix', 0, 0, 1),
#  ('cLdxuaxaQwc', 'fuckniggers', 0, 0, 0),
#  ('cLdxuaxaQwc',
#   'nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger nigger  ...
#   0,
#   0,
#   0),
#  ('cLdxuaxaQwc', None, 0, 0, 0),
#  ('cLdxuaxaQwc', 'negerboll', 0, 0, 0),
#  ('WYYvHb03Eog', 'what wanna unlock phone while dark', 0, 0, -1),
#  ('WYYvHb03Eog',
#   'will girls unlock their iphone after taking their makeup',
#   1,
#   0,
#   0),
#  ('WYYvHb03Eog', 'said once again only sniff poop', 0, 0, 0),
#  ('WYYvHb03Eog', 'could sworn asked group facetime call', 0, 0, 0),
#  ('WYYvHb03Eog', 'what wearing sunglasses', 0, 0, 0),
#  ('WYYvHb03Eog', 'many people wana face security flaw', 0, 0, 1),
#  ('WYYvHb03Eog', 'watch clicking icon people entertaining', 1, 0, 1),
#  ('WYYvHb03Eog', 'still iphone headphone jack finger print sensor', 0, 0, 0),
#  ('WYYvHb03Eog', 'just impressed', 0, 0, 1),
#  ('WYYvHb03Eog', 'looks outdated with chrome', 0, 0, -1),
#  ('WYYvHb03Eog', 'still made china', 0, 0, 0),
#  ('WYYvHb03Eog',
#   'time technology turned iphone cheaper settle down with secondhanded have skipped anyway definitely',
#   0,
#   0,
#   -1),
#  ('WYYvHb03Eog', 'chinese going secure their phones', 0, 0, 1),
#  ('WYYvHb03Eog',
#   'phone itself looks pretty great worth wait while before buying price lower march next year probably gonna same price iphone',
#   0,
#   0,
#   1),
#  ('WYYvHb03Eog', 'thank great phone know many things with that', 0, 0, 1),
#  ('WYYvHb03Eog',
#   'apple iphones years past before being overcome with boredom stemming from stagnant design underwhelming yearly reveals currently loving gorgeous plus however iphone absolutely beautiful first time years actually kind excited about apple product also wait samsung responds competition means better products consumers nice work apple',
#   0,
#   0,
#   1),
#  ('WYYvHb03Eog', 'xcuse what price again', 0, 0, 0),
#  ('WYYvHb03Eog', 'what dark recognise youre face unlock', 0, 0, -1),
#  ('WYYvHb03Eog',
#   'damn wonder much longer until looking like futuristic movie',
#   0,
#   0,
#   1),
#  ('WYYvHb03Eog',
#   'apple doing good copying samsung whatever happened being innovative this just overpriced android with apple logo',
#   0,
#   0,
#   1),
#  ('WYYvHb03Eog', 'apple friends probably automatically hate', 0, 0, -1),
#  ('WYYvHb03Eog', 'anyone else appreciate their more', 0, 0, 1),
#  ('WYYvHb03Eog',
#   'really like home button like touch more then this face',
#   0,
#   0,
#   1),
#  ('WYYvHb03Eog',
#   'when google face unlock several years entire tech press dismissed gimmick best thing since sliced bread',
#   0,
#   0,
#   1),
#  ('WYYvHb03Eog', 'those prices though stay with', 0, 0, 0),
#  ('WYYvHb03Eog',
#   'feel like with home button constantly going accidentally open apps bottom screen',
#   0,
#   0,
#   0),
#  ('WYYvHb03Eog',
#   'iphones cool people samsungs androids immigrants people that what noticed',
#   0,
#   0,
#   1),
#  ('WYYvHb03Eog',
#   'this thing orwellian nightmare george orwell couldn think anything better drug induced dream apple should',
#   0,
#   0,
#   1),
#  ('WYYvHb03Eog', 'wait just need sell kidney afford iphone', 0, 0, 0),
#  ('WYYvHb03Eog',
#   'people here work think this phone best phone ever made other phone features will have listen them lunch table browsing youtube smiling',
#   0,
#   0,
#   1),
#  ('WYYvHb03Eog', 'they button', 0, 0, 0),
#  ('WYYvHb03Eog', 'loves apple users most', 0, 0, 1),
#  ('WYYvHb03Eog',
#   'bout time apple been rocking iphone since start nothing changed finally something great',
#   0,
#   0,
#   1),
#  ('WYYvHb03Eog',
#   'they stop comin they stop commin they stop commin they stop comm',
#   0,
#   0,
#   0),
#  ('WYYvHb03Eog', 'back uglier than iphone four', 0, 0, 0),
#  ('WYYvHb03Eog', 'thank stuck with last they sold', 0, 0, 0),
#  ('WYYvHb03Eog',
#   'remember when apple innovator every those features available samsung they should just copied infinity display would made look much nicer',
#   0,
#   0,
#   1),
#  ('WYYvHb03Eog', 'this phone reminded iphone glad that', 0, 0, 1),
#  ('WYYvHb03Eog', 'techrax gonna happy', 0, 0, 1),
#  ('WYYvHb03Eog', 'what night face recognition', 0, 0, 0),
#  ('WYYvHb03Eog', 'copy samsung', 0, 0, 0),
#  ('WYYvHb03Eog', 'from', 0, 0, 0),
#  ('WYYvHb03Eog',
#   'stealing having home button just like samsung galaxy',
#   0,
#   0,
#   0),
#  ('WYYvHb03Eog', 'that iphone different', 0, 0, 0),
#  ('WYYvHb03Eog', 'just waste money samsung galaxy note better', 0, 0, 1),
#  ('WYYvHb03Eog',
#   'apple never named their iphones with numbered like jordan shoes every year iphone would have been released last year after releasing different iphone models confusing having nthis what apple should have done without naming iphone iphone instead iphone instead iphone iphone instead iphone instead iphone instead iphone viii instead iphone instead iphone instead iphone instead nonly first iphone iphone were named properly poor iphone doesn model next year remove numerics refer only iphone same numerics longer exist ipads macbook',
#   0,
#   0,
#   -1),
#  ('WYYvHb03Eog',
#   'look camera they using film iphone seeing blasts coming from sensor',
#   0,
#   0,
#   0),
#  ('WYYvHb03Eog', 'home button laughs android', 0, 0, 0),
#  ('WYYvHb03Eog', 'just wait sell kidney', 0, 0, 0),
#  ('WYYvHb03Eog',
#   '#apple have released another #chinese clone seems taking last years #tech already seen throwing into device twice price haven seen #groundbreaking moves from #apple many years even computers being #owned competitors',
#   0,
#   0,
#   1),
#  ('WYYvHb03Eog', 'xbox most powerfull console iphone love', 0, 0, 1),
#  ('WYYvHb03Eog', 'back ugly', 0, 0, -1),
#  ('WYYvHb03Eog',
#   'someone help this phone anyone come millionaires billionaires anyone help',
#   0,
#   0,
#   0),
#  ('WYYvHb03Eog', 'looks like samsung', 0, 0, 0),
#  ('WYYvHb03Eog', 'inches larger iphone inches button', 0, 0, 0),
#  ('WYYvHb03Eog', 'done going back flip phones where motorola razr', 0, 0, 0),
#  ('WYYvHb03Eog',
#   'face recognition most stupid thing ever into just fast with more simplicity with pattern lock just does that look like past display screen complete opposite infinity screen looks ugly',
#   0,
#   0,
#   -1),
#  ('WYYvHb03Eog',
#   'apple claims this first oled screen which good enough iphone lesser screen claim bullshit thing about this good enough stuff about profit margins',
#   0,
#   0,
#   1),
#  ('WYYvHb03Eog', 'guys giving more reasons swich back iphone', 0, 0, 1),
#  ('WYYvHb03Eog',
#   'phone looks cool front back sides look awful especially with that glass back camera like iphone smooth like iphone smooth',
#   0,
#   0,
#   1),
#  ('WYYvHb03Eog', 'android done this already original', 0, 0, 1),
#  ('WYYvHb03Eog', 'without charging port still gonna', 0, 0, 0),
#  ('WYYvHb03Eog', 'could only afford', 1, 0, 0),
#  ('WYYvHb03Eog', 'looks like glass iphone that effect death', 1, 0, 0),
#  ('WYYvHb03Eog',
#   'made china only imagine made talk about high profit margin apple such scam nhttps cnbc apple earnings much cash does apple have html',
#   0,
#   0,
#   1),
#  ('WYYvHb03Eog',
#   'features flagship android phones have years such wireless charging face unlock still hilariously convinces people that revolutionary worth over napple brilliant',
#   1,
#   0,
#   1),
#  ('WYYvHb03Eog',
#   'wanted better phone wanted camera would have bought nikon',
#   1,
#   0,
#   1),
#  ('WYYvHb03Eog',
#   'they should have fingerprint scanner apple logo back phone',
#   1,
#   0,
#   0),
#  ('WYYvHb03Eog', 'gonna just because gonna better snap chat filters', 1, 0, 1),
#  ('WYYvHb03Eog', 'didn just come', 1, 0, 0),
#  ('WYYvHb03Eog', 'copy samsung much', 0, 0, 1),
#  ('WYYvHb03Eog', 'absolutely beautiful apple dollars xpensive', 0, 0, 1),
#  ('WYYvHb03Eog', 'tmobile jump', 0, 0, 0),
#  ('WYYvHb03Eog', 'highkey copied samsung', 1, 0, 0),
#  ('WYYvHb03Eog', 'samsung better', 0, 0, 1),
#  ('WYYvHb03Eog', 'iphone xpensive', 0, 0, 0),
#  ('WYYvHb03Eog', 'apple disabled comments cowards', 0, 0, -1),
#  ('WYYvHb03Eog', 'what happened iphone', 0, 0, 0),
#  ('WYYvHb03Eog', 'dont', 0, 0, 0),
#  ('WYYvHb03Eog', 'happened with', 0, 0, 0),
#  ('WYYvHb03Eog', 'they copied meizu haha', 0, 0, 1),
#  ('WYYvHb03Eog', 'headphone jack', 0, 0, 0),
#  ('WYYvHb03Eog', 'south korea still wins', 0, 0, 1),
#  ('WYYvHb03Eog', 'samsung galaxy already copy this', 0, 0, 0),
#  ('WYYvHb03Eog', 'battery', 0, 0, 0),
#  ('WYYvHb03Eog', 'welp aint gettin this anytime soon rich', 0, 0, 1),
#  ('WYYvHb03Eog', 'what about', 0, 0, 0),
#  ('WYYvHb03Eog', 'mean samsung galaxy', 0, 0, -1),
#  ('WYYvHb03Eog', 'apple iphone amazing', 0, 0, 1),
#  ('WYYvHb03Eog', 'here review noverpriced smartphone', 0, 0, 0),
#  ('WYYvHb03Eog', 'nope', 0, 0, 0),
#  ('WYYvHb03Eog', 'copy', 0, 0, 0),
#  ('WYYvHb03Eog', 'rear looks shyt though', 0, 0, 0),
#  ('WYYvHb03Eog', 'oooooh looks breakable good thang dallars', 0, 0, 1),
#  ('WYYvHb03Eog', 'where techrax', 0, 0, 0),
#  ('WYYvHb03Eog', 'happened iphone', 0, 0, 0),
#  ('WYYvHb03Eog', 'https youtu vasyweuqfd', 0, 0, 0),
#  ('WYYvHb03Eog', 'waste money', 1, 0, -1),
#  ('WYYvHb03Eog', 'knock', 1, 0, 0),
#  ('WYYvHb03Eog',
#   'samsung make this nevermind that would insult samsung there amazing design team android these features years nothing even samsung galaxy feature unlock your phone with your face years nothing invented here with apple',
#   1,
#   1,
#   1),
#  ('sjlHnJvXdQs',
#   'nothing scarier than replying every comment with advertisement channel',
#   3,
#   0,
#   0),
#  ('sjlHnJvXdQs', None, 0, 0, 0),
#  ('sjlHnJvXdQs', 'jacksfilms sarcasm comedian', 0, 0, 0),
#  ('sjlHnJvXdQs', 'iphone majmol barmok', 0, 0, 0),
#  ('sjlHnJvXdQs', 'iphone imbibing review https youtu mkzihjq', 0, 0, 0),
#  ('sjlHnJvXdQs', 'congrats getting this trending john', 0, 0, 0),
#  ('sjlHnJvXdQs', 'what happened iphone', 0, 0, 0),
#  ('sjlHnJvXdQs', 'ahahah lmao', 0, 0, 1),
#  ('sjlHnJvXdQs', 'this priceless', 0, 0, 1),
#  ('sjlHnJvXdQs', 'trending', 0, 0, 0),
#  ('sjlHnJvXdQs', 'emoji movie porn #yiayfetish', 0, 0, 0),
#  ('sjlHnJvXdQs', 'true true', 0, 0, 1),
#  ('sjlHnJvXdQs', 'hiii', 0, 0, 0),
#  ('sjlHnJvXdQs', 'trending', 0, 0, 0),
#  ('sjlHnJvXdQs', 'emoji machine nomfg cringe', 0, 0, 0),
#  ('sjlHnJvXdQs', 'most disappointing apple event ever', 0, 0, -1),
#  ('sjlHnJvXdQs', 'apple went full retard', 0, 0, -1),
#  ('sjlHnJvXdQs', 'this hilarious', 0, 0, 1),
#  ('sjlHnJvXdQs', 'idiot', 0, 0, -1),
#  ('sjlHnJvXdQs', 'there goes spondsor', 0, 0, 0),
#  ('sjlHnJvXdQs', 'summed perfectly', 0, 0, 1),
#  ('sjlHnJvXdQs', 'absolutely brilliant outdone yourself jack', 0, 0, 1),
#  ('sjlHnJvXdQs', 'make more parodies', 0, 0, 1),
#  ('sjlHnJvXdQs', 'animoji movie coming', 0, 0, 0),
#  ('sjlHnJvXdQs', 'this video awesome', 0, 0, 1),
#  ('sjlHnJvXdQs',
#   'apple emoji machine with fidget spinner emojis whispering being payed sony advertise fidget spinners movie whispering forgot include least snes minis',
#   0,
#   0,
#   -1),
#  ('sjlHnJvXdQs', 'this awesome xddddddddd', 0, 0, 1),
#  ('sjlHnJvXdQs', 'dementor lmao', 0, 0, 1),
#  ('sjlHnJvXdQs', 'freakin cosplay simulator', 0, 0, 0),
#  ('sjlHnJvXdQs',
#   'never been prouder been subber like years this video newssites',
#   0,
#   0,
#   0),
#  ('sjlHnJvXdQs', 'this true', 0, 0, 1),
#  ('sjlHnJvXdQs',
#   'iphone face unlock work scroll become poop emoji nstarting',
#   1,
#   0,
#   0),
#  ('sjlHnJvXdQs', 'product much', 0, 0, 1),
#  ('sjlHnJvXdQs', 'watch clicking here people entertaining', 1, 0, 1),
#  ('sjlHnJvXdQs',
#   'jack literally just commented last video crying right',
#   0,
#   0,
#   1),
#  ('sjlHnJvXdQs', 'feel trending', 0, 0, 0),
#  ('sjlHnJvXdQs', 'thank your life juice', 0, 0, 0),
#  ('sjlHnJvXdQs',
#   'video trending about great things about apple video trending this dissing like crap',
#   0,
#   0,
#   0),
#  ('sjlHnJvXdQs', 'should have waited until tenth iphone call', 0, 0, 0),
#  ('sjlHnJvXdQs',
#   'this video reminds sister because think penguin costumes clumsy said similar things back like with that webpage',
#   0,
#   0,
#   -1),
#  ('sjlHnJvXdQs', 'this what steve would have wanted nprobably', 0, 0, 0),
#  ('sjlHnJvXdQs', 'clickbait expecting parody real thing reuploaded', 0, 0, 1),
#  ('sjlHnJvXdQs',
#   'jack this video just shown news show netherlands cool great',
#   0,
#   0,
#   1),
#  ('sjlHnJvXdQs', 'wuahaha comes with colors cant afford', 0, 0, 0),
#  ('sjlHnJvXdQs',
#   'hope apple loses money cause after iphone been shit',
#   0,
#   0,
#   -1),
#  ('sjlHnJvXdQs', 'just back from grade camp', 0, 0, 0),
#  ('sjlHnJvXdQs', 'only paying company samsung better than apple', 0, 0, 1),
#  ('sjlHnJvXdQs',
#   'honestly thought only that like they serious official people only iphones name iphone because they have anything offer nothing full crap what understand what hell that',
#   0,
#   0,
#   -1),
#  ('sjlHnJvXdQs', 'fuck pays iphone', 0, 0, -1),
#  ('sjlHnJvXdQs',
#   'maybe this just marketing plot more people watch between seasons',
#   0,
#   0,
#   1),
#  ('sjlHnJvXdQs', 'jack speaks truth', 1, 0, 0),
#  ('sjlHnJvXdQs', 'this actually original', 1, 0, 1),
#  ('sjlHnJvXdQs', 'simple person iphone video click', 0, 0, 0),
#  ('sjlHnJvXdQs', 'thank hate apple thinking this kinda idea', 0, 0, -1),
#  ('sjlHnJvXdQs', 'more using your phone while charging', 1, 0, 1),
#  ('sjlHnJvXdQs',
#   'that pretty hilarious also accurate that stick with android because apple damn expensive',
#   0,
#   0,
#   1),
#  ('sjlHnJvXdQs',
#   'always intriguing some people upset over other people choice phone',
#   0,
#   0,
#   1),
#  ('sjlHnJvXdQs', 'best accurate description those apple products', 0, 0, 1),
#  ('sjlHnJvXdQs',
#   'thanks apple confused they just release iphone same time making obsolete also what with these software companies they hatred number',
#   0,
#   0,
#   -1),
#  ('sjlHnJvXdQs', 'here india iphone will cost', 0, 0, 0),
#  ('sjlHnJvXdQs',
#   'gaming that allows play games phone that allows watch games with black such hard decision',
#   0,
#   0,
#   -1),
#  ('sjlHnJvXdQs', 'really wanna that emoji machine', 0, 0, 1),
#  ('sjlHnJvXdQs', 'dementor part cracks', 0, 0, 0),
#  ('sjlHnJvXdQs', 'this quality content subscribed', 0, 0, 0),
#  ('sjlHnJvXdQs', 'said wrong switches games', 0, 0, -1),
#  ('sjlHnJvXdQs',
#   'steve jobs vision sell stuff make money change world',
#   0,
#   0,
#   0),
#  ('sjlHnJvXdQs',
#   'even getting half full screen experience galaxy with lower resolution notch that blocks your view hard press home button',
#   0,
#   0,
#   -1),
#  ('sjlHnJvXdQs',
#   'know damn apple seriously iphone when almost exactly like iphone slight with more nucleus save money iphone better save your money more years price will drop enough after iphone come',
#   0,
#   0,
#   1),
#  ('sjlHnJvXdQs',
#   'know what really grinds gears iphone america costs which should about they still charge',
#   0,
#   0,
#   1),
#  ('sjlHnJvXdQs',
#   'ever since steve jobs passed away iphone gone shit iphones sooo good like seriously wireless charging samsung implemented generation with lmao',
#   0,
#   0,
#   1),
#  ('sjlHnJvXdQs', 'should parody', 0, 0, 0),
#  ('sjlHnJvXdQs', 'wants this phone afford', 0, 0, 1),
#  ('sjlHnJvXdQs',
#   'local radio station played audio clip from your video',
#   0,
#   0,
#   0),
#  ('sjlHnJvXdQs',
#   'told nintendo that switch wouldn success before went sale because thought that smartphone would carry around game console tsunekazu ishihara',
#   0,
#   0,
#   -1),
#  ('sjlHnJvXdQs', 'they made easy hahaha emoji machine', 1, 0, 1),
#  ('sjlHnJvXdQs', 'where parody', 1, 0, 0),
#  ('sjlHnJvXdQs', 'dementor part funny proud jack', 0, 0, 1),
#  ('sjlHnJvXdQs', 'ohohoho said laughing like walrus', 0, 0, 0),
#  ('sjlHnJvXdQs',
#   'just redbull iphones being abandoned their owners have feeling they gonna have some company soon',
#   0,
#   0,
#   0),
#  ('sjlHnJvXdQs',
#   'work famous french media called minutebuzz have more than million people facebook https facebook profile fref love your video would like post facebook page hero nwould cool with that course will mention your page post description nbest regards',
#   0,
#   0,
#   1),
#  ('sjlHnJvXdQs', 'about status power', 0, 0, 0),
#  ('sjlHnJvXdQs', 'colors cant afford', 0, 0, 0),
#  ('sjlHnJvXdQs', 'this really informative enlightening thank jack', 0, 0, 1),
#  ('sjlHnJvXdQs',
#   'said nothing about iphone just like completely different',
#   0,
#   0,
#   0),
#  ('sjlHnJvXdQs', 'shut take kidney', 0, 0, 0),
#  ('sjlHnJvXdQs', 'used real video times', 0, 0, 1),
#  ('sjlHnJvXdQs', 'this accurate fuck love', 0, 0, 1),
#  ('sjlHnJvXdQs',
#   'hhaha funny video loved check video that shows funniest memes tweets about iphone https kwxrvr',
#   0,
#   0,
#   1),
#  ('sjlHnJvXdQs',
#   'ohohohohohoh hoho ohhoh clap clap said culmination here',
#   0,
#   0,
#   0),
#  ('sjlHnJvXdQs',
#   'here remembers when jack parodies once week once year',
#   0,
#   0,
#   0),
#  ('sjlHnJvXdQs', 'would rather brand', 1, 0, 0),
#  ('sjlHnJvXdQs', None, 1, 0, 0),
#  ('sjlHnJvXdQs', 'borrow your dongle', 1, 0, 0),
#  ('sjlHnJvXdQs', '#yiayfetish alexander hamilton', 0, 0, 0),
#  ('sjlHnJvXdQs', 'trending', 1, 0, 0),
#  ('sjlHnJvXdQs', 'film tube channel', 1, 0, 0),
#  ('sjlHnJvXdQs', 'love this video', 1, 0, 1),
#  ('sjlHnJvXdQs', 'take switches games please', 1, 0, 0),
#  ('sjlHnJvXdQs',
#   'that apple fingerprints right time collect faces thank apple ncan wait donate liver next iphone drop blood drops safe unlock keep good work',
#   1,
#   0,
#   1),
#  ('sjlHnJvXdQs', 'this brilliant nthe emoji machine your video john', 1, 0, 1),
#  ('cMKX2tE5Luk', 'sure speak everyone when wait tearing apart', 3, 0, 1),
#  ('cMKX2tE5Luk', 'https youtu xbjtnahvlag', 0, 0, 0),
#  ('cMKX2tE5Luk',
#   'this looks like another masterpiece bravo tommy approved #theroom',
#   1,
#   0,
#   0),
#  ('cMKX2tE5Luk', 'check https youtube watch gngmjvmyk', 0, 0, 0),
#  ('cMKX2tE5Luk', 'this looks cool', 0, 0, 1),
#  ('cMKX2tE5Luk', 'this sooo cool', 0, 0, 1),
#  ('cMKX2tE5Luk', 'doggy', 0, 0, 0),
#  ('cMKX2tE5Luk', 'mark', 0, 0, 0),
#  ('cMKX2tE5Luk', 'chip chip chip chip chip', 0, 0, 0),
#  ('cMKX2tE5Luk', 'holy shit franco nails', 0, 0, -1),
#  ('cMKX2tE5Luk', 'someone watched nostalgia critic lmao', 0, 0, 1),
#  ('cMKX2tE5Luk', 'doggy', 0, 0, 0),
#  ('cMKX2tE5Luk',
#   'subscribe please https youtube channel ucsvj wybjutg',
#   0,
#   0,
#   0),
#  ('cMKX2tE5Luk', 'beautiful', 0, 0, 1),
#  ('cMKX2tE5Luk', 'last scene lmao', 0, 0, 1),
#  ('cMKX2tE5Luk', 'cant wait', 0, 0, 0),
#  ('cMKX2tE5Luk', 'yeeeeeeesssssssssssssssssss', 0, 0, 0),
#  ('cMKX2tE5Luk', 'best movie ever', 0, 0, 1),
#  ('cMKX2tE5Luk', 'excited', 0, 0, 1),
#  ('cMKX2tE5Luk', 'boyutiful', 0, 0, 0),
#  ('cMKX2tE5Luk', None, 0, 0, 0),
#  ('cMKX2tE5Luk', 'http formoneyonly refer', 0, 0, 0),
#  ('cMKX2tE5Luk', 'behind scene https youtu xtkkb', 0, 0, -1),
#  ('cMKX2tE5Luk', 'does disappoint', 0, 0, 0),
#  ('cMKX2tE5Luk', None, 0, 0, 0),
#  ('cMKX2tE5Luk', 'this this looks beautiful', 0, 0, 1),
#  ('cMKX2tE5Luk', 'omfg lets already', 0, 0, 0),
#  ('cMKX2tE5Luk', 'nooooooot', 0, 0, 0),
#  ('cMKX2tE5Luk', 'mark', 0, 0, 0),
#  ('cMKX2tE5Luk', 'fucking pewd make this famous', 0, 0, -1),
#  ('cMKX2tE5Luk', 'this actually looks cool', 0, 0, 1),
#  ('cMKX2tE5Luk', 'seth rogen seth rogen', 0, 0, 0),
#  ('cMKX2tE5Luk', 'watch clicking here people entertaining', 1, 0, 1),
#  ('cMKX2tE5Luk', 'does with long hair look like john mayer', 0, 0, -1),
#  ('cMKX2tE5Luk',
#   'power disease care cure keep caring yourself others best this life',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk',
#   'this looks like great video after done would kind enough check youtube channel give some feedback maybe even subscribing',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk', 'where park flying mercedes', 0, 0, 0),
#  ('cMKX2tE5Luk', 'want watch this', 0, 0, 0),
#  ('cMKX2tE5Luk', 'been waiting since greg book came excited', 0, 0, 1),
#  ('cMKX2tE5Luk',
#   'next thing know tommy wiseau stage accepting best picture',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk', 'friends please subscribe channel', 0, 0, 0),
#  ('cMKX2tE5Luk', 'james does that voice fucking well holy shit', 0, 0, -1),
#  ('cMKX2tE5Luk', 'this made room movie', 0, 0, 0),
#  ('cMKX2tE5Luk',
#   'wish original story with tommy instead having remember earlier project almost like this film making work',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk', 'does voice good', 0, 0, 1),
#  ('cMKX2tE5Luk', 'know have seen anything more spot life', 0, 0, 1),
#  ('cMKX2tE5Luk',
#   'great trailer could more excited this movie also anyone know song name',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk', 'first didn like that voice grew', 0, 0, 1),
#  ('cMKX2tE5Luk', 'greatest movie about greatest movie', 0, 0, 1),
#  ('cMKX2tE5Luk', 'doesn disappoint there movie seen good', 0, 0, 1),
#  ('cMKX2tE5Luk', 'james franco could earn oscar nomination this', 0, 0, 0),
#  ('cMKX2tE5Luk',
#   'believe video kittens outside over million views check that subscribe button xoxo sarina nhttps youtu dcjk ajckg',
#   0,
#   0,
#   0),
#  ('cMKX2tE5Luk', 'full retard half retard tell', 0, 0, -1),
#  ('cMKX2tE5Luk', 'still believe that original movie made', 0, 0, 1),
#  ('cMKX2tE5Luk',
#   'justice league thor star wars damned this most anticipated upcoming movie',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk', 'have never been more excited film', 0, 0, 1),
#  ('cMKX2tE5Luk', 'hope vampire finale some sort', 0, 0, 0),
#  ('cMKX2tE5Luk', 'insert room quote here', 0, 0, 0),
#  ('cMKX2tE5Luk', 'anyone wondering james life', 0, 0, 0),
#  ('cMKX2tE5Luk', 'anyone know song that starts', 0, 0, 0),
#  ('cMKX2tE5Luk', 'really wanna watch this', 0, 0, 1),
#  ('cMKX2tE5Luk',
#   'totally wait this movie james franco does good tommy wiseau',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk', 'this thing this year that want just', 0, 0, 0),
#  ('cMKX2tE5Luk', 'naaaaaaaaht', 0, 0, 0),
#  ('cMKX2tE5Luk', 'what song name', 0, 0, 0),
#  ('cMKX2tE5Luk',
#   'really want some kind video wiseau responding this movie',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk',
#   'didn they hire greg himself tell they want good actor instead they hired dave franco seth lithel brader',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk',
#   'having seen original going much please everyone room before seeing this',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk',
#   'damn james franco soooo good sounds exactly like real',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk',
#   'these brothers seem like best friends wish could close brother thing have',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk', 'harry guys spiderman best friend', 0, 0, 1),
#  ('cMKX2tE5Luk',
#   'imagine what james franco nominated oscar this role',
#   0,
#   0,
#   0),
#  ('cMKX2tE5Luk',
#   'wouldn most ironic thing ever this movie gets james franco oscar nomination',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk',
#   'wait this december definitely oscar nominations coming',
#   0,
#   0,
#   0),
#  ('cMKX2tE5Luk', 'think prefer room itself', 0, 0, 0),
#  ('cMKX2tE5Luk',
#   'book true literary masterpiece just like movie room',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk', 'name song marino communication', 0, 0, 0),
#  ('cMKX2tE5Luk', 'damn accurate', 0, 0, 1),
#  ('cMKX2tE5Luk',
#   'after seeing teaser little concerned about james franco accent anymore that spot this looks fantastic just because accent cannot wait this',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk', 'this great fake trailer', 0, 0, 1),
#  ('cMKX2tE5Luk', 'performance looks much better than teaser', 0, 0, 1),
#  ('cMKX2tE5Luk',
#   'never famous million years nbut after that holy shit that such good quote',
#   0,
#   0,
#   1),
#  ('cMKX2tE5Luk', 'maybe johnny vampire', 0, 0, 0),
#  ('cMKX2tE5Luk', 'best remake ever', 1, 0, 1),
#  ('cMKX2tE5Luk', 'belly', 1, 0, 0),
# ...
#   1),
#  ('_ANP3HR1jsM', 'roman your goat', 1, 0, 0),
#  ('_ANP3HR1jsM', 'cora cute wait untill speaks else', 1, 0, 1),
#  ('_ANP3HR1jsM', 'hate people always edit their comments', 1, 0, -1),
#  ('_ANP3HR1jsM', 'have twitter', 1, 0, 0),
#  ('_ANP3HR1jsM', 'forgot what happened razor', 1, 0, 0),
#  ('_ANP3HR1jsM', 'check latest vlog guys', 0, 2, 1),
#  ('zgLtEob6X-Q', 'will never read your comment ever', 0, 0, 0),
#  ('zgLtEob6X-Q',
#   'please brendan fraser trilogy nplease please please',
#   0,
#   0,
#   0),
#  ('zgLtEob6X-Q', 'book from original mummy there', 0, 0, 1),
#  ('zgLtEob6X-Q',
#   'this looks like great video after done would kind enough check youtube channel give some feedback maybe even subscribing',
#   0,
#   0,
#   1),
#  ('zgLtEob6X-Q', 'last scene dessert funny though', 0, 0, 1),
#  ('zgLtEob6X-Q',
#   'fact nthey didnt even shoot egypt they shot different desert pyramids',
#   0,
#   0,
#   0),
#  ('zgLtEob6X-Q', 'gotta room with disaster artist trailer release', 0, 0, 0),
#  ('zgLtEob6X-Q',
#   'need honest trailer room before disaster artist comes',
#   0,
#   0,
#   1),
#  ('zgLtEob6X-Q',
#   'please honest trailer justice league animated series justice league flashpoint paradox',
#   0,
#   0,
#   1),
#  ('zgLtEob6X-Q', 'outta closet cruise subscribe', 0, 0, 0),
#  ('zgLtEob6X-Q', 'mobile please sold feels gooooood', 0, 0, 0),
#  ('zgLtEob6X-Q', 'reading random comment', 0, 0, -1),
#  ('zgLtEob6X-Q', 'trailer', 0, 0, 0),
#  ('zgLtEob6X-Q', 'movie that even this honest trailer sucked', 0, 0, 1),
#  ('zgLtEob6X-Q', 'beni looks like wrong side riveeeeeeeeeer', 0, 0, -1),
#  ('zgLtEob6X-Q',
#   'alright just like other action romance comedy nothing special best character mummy died dark series just began',
#   0,
#   0,
#   1),
#  ('zgLtEob6X-Q', 'gotta case swamp itches', 0, 0, 0),
#  ('zgLtEob6X-Q', 'this sick', 0, 0, -1),
#  ('zgLtEob6X-Q', 'please also daaaaaaan', 0, 0, 0),
#  ('zgLtEob6X-Q', 'guardians that russian superhero movie', 0, 0, 0),
#  ('zgLtEob6X-Q', 'were still nice them', 0, 0, 1),
#  ('zgLtEob6X-Q', 'love these videos', 0, 0, 1),
#  ('zgLtEob6X-Q', 'best part movie credits', 0, 0, 1),
#  ('zgLtEob6X-Q', 'honestly people hate easter eggs much', 0, 0, -1),
#  ('zgLtEob6X-Q', 'amazing spider universal monsters edition', 0, 0, 1),
#  ('zgLtEob6X-Q', 'movie okay', 0, 0, 1),
#  ('zgLtEob6X-Q', 'honest trailer room mark', 0, 0, 1),
#  ('zgLtEob6X-Q', 'quality videos getting each honest trailer', 0, 0, 1),
#  ('zgLtEob6X-Q', 'liked movie', 0, 0, 1),
#  ('zgLtEob6X-Q',
#   'cruise alex kurtzman were problems universal months make adjustments what went right what went wrong with mummy before bride frankenstein hits screen',
#   0,
#   0,
#   -1),
#  ('zgLtEob6X-Q', 'rick morty already', 0, 0, 0),
#  ('zgLtEob6X-Q', 'they made mummy would kill', 0, 0, 0),
#  ('zgLtEob6X-Q',
#   'anyone else think that cruise would make good nathan drake',
#   0,
#   0,
#   1),
#  ('zgLtEob6X-Q', 'thought from warner brothers', 0, 0, 0),
#  ('zgLtEob6X-Q', 'cruise runs from sand featuring mummy haha', 0, 0, 1),
#  ('zgLtEob6X-Q', 'original stephen king', 0, 0, 1),
#  ('zgLtEob6X-Q', 'please just baggage handler', 0, 0, 0),
#  ('zgLtEob6X-Q', 'hold fuvk netflix included', 0, 0, 0),
#  ('zgLtEob6X-Q', 'disappointing this movie', 0, 0, -1),
#  ('zgLtEob6X-Q',
#   'someone likes brandon fraser mummy films this remake spider sense going from beginning',
#   0,
#   0,
#   0),
#  ('zgLtEob6X-Q',
#   'second russel crowe went name jekyll henry jekyll quit screw this movie dank universe acting careers ruined especially screw whatever they were planning doing with dracula nunless dracula untold supposed this universe screw that movie',
#   0,
#   0,
#   0),
#  ('zgLtEob6X-Q',
#   'what find that they chose clip from hunchback notre dame represent universal monsters',
#   0,
#   0,
#   0),
#  ('zgLtEob6X-Q', 'play world ngermany back nand this time personal', 0, 0, 0),
#  ('zgLtEob6X-Q', 'correction cruise runs from sand again', 0, 0, 0),
#  ('zgLtEob6X-Q',
#   'look screen junkie love honest trailer will continue loving recent videos miss something that done well past pauses know that have keep track with hype quantity also require quality just before joking take seconds silent appreciate guys take time read comment',
#   0,
#   0,
#   1),
#  ('zgLtEob6X-Q',
#   'please honest trailer that could funny with movie controversial topics',
#   0,
#   0,
#   1),
#  ('zgLtEob6X-Q', 'please think anything actually', 0, 0, 0),
#  ('zgLtEob6X-Q',
#   'ever going unfriended been asking years nowplease unfriended soon',
#   0,
#   0,
#   0),
#  ('zgLtEob6X-Q', 'time wonder woman honest trailer', 0, 0, 1),
#  ('zgLtEob6X-Q', 'look thirsty', 0, 0, 0),
#  ('zgLtEob6X-Q',
#   'downloaded mummy best quality guys here iink https twitter akewdiudri status nyou must guys that awesome',
#   0,
#   0,
#   1),
#  ('zgLtEob6X-Q', 'gonna read good comment chose yours instead', 0, 0, 1),
#  ('zgLtEob6X-Q', 'this movie that much', 0, 0, 1),
#  ('zgLtEob6X-Q', 'what', 0, 0, 0),
#  ('zgLtEob6X-Q', 'brendan fraser mummy please', 0, 0, 0),
#  ('zgLtEob6X-Q', 'please what would klondike', 0, 0, 0),
#  ('zgLtEob6X-Q',
#   'your channel throwing error saying this cant found this server when ever share',
#   0,
#   0,
#   0),
#  ('zgLtEob6X-Q', 'dude horror movie', 0, 0, 0),
#  ('zgLtEob6X-Q', 'please american made decent movie', 1, 0, 1),
#  ('zgLtEob6X-Q',
#   'fact this actually second attempt dark universe first dracula untold which much better movie than mummy',
#   1,
#   0,
#   1),
#  ('zgLtEob6X-Q', 'this love honest trailers they savage', 1, 0, 1),
#  ('zgLtEob6X-Q', 'should movie next', 1, 0, 0),
#  ('zgLtEob6X-Q', 'this recommendations', 1, 0, 0),
#  ('zgLtEob6X-Q', 'remake considered original', 1, 0, 1),
#  ('zgLtEob6X-Q', 'like apples', 1, 0, 0),
#  ('zgLtEob6X-Q', 'snow song fire', 1, 0, 0),
#  ('zgLtEob6X-Q', 'sponsored mobile', 0, 0, 0),
#  ('zgLtEob6X-Q', 'cruise rapes dead donkeys just saying', 0, 0, -1),
#  ('zgLtEob6X-Q', 'baby driver', 0, 0, 0),
#  ('zgLtEob6X-Q', 'tremors', 0, 0, 0),
#  ('zgLtEob6X-Q', None, 0, 0, 0),
#  ('zgLtEob6X-Q', 'honest trailer holograms', 0, 0, 1),
#  ('zgLtEob6X-Q', 'alien please', 0, 0, -1),
#  ('zgLtEob6X-Q', 'please ameterasu', 0, 0, 0),
#  ('zgLtEob6X-Q', 'piiickleee riiiiiick', 0, 0, 0),
#  ('zgLtEob6X-Q', 'wilder', 0, 0, 0),
#  ('zgLtEob6X-Q', 'cars', 0, 0, 0),
#  ('zgLtEob6X-Q', 'wonder woman', 0, 0, 0),
#  ('zgLtEob6X-Q', 'reenact star wars movie vsshh vsshh boom', 0, 0, 0),
#  ('zgLtEob6X-Q', 'please omae shindeiru', 0, 0, 0),
#  ('zgLtEob6X-Q', 'please uncle touchy prease honest trailer prease', 0, 0, 1),
#  ('zgLtEob6X-Q', 'thank', 0, 0, 0),
#  ('zgLtEob6X-Q', 'great review', 0, 0, 1),
#  ('zgLtEob6X-Q', 'wait tmobile gives free netflix', 0, 0, 1),
#  ('zgLtEob6X-Q', 'stop', 0, 0, 0),
#  ('zgLtEob6X-Q', 'baby driver', 0, 0, 0),
#  ('zgLtEob6X-Q', None, 0, 0, 0),
#  ('zgLtEob6X-Q', 'need wonderwoman honest trailer', 0, 0, 1),
#  ('zgLtEob6X-Q', 'guys lifeforce', 0, 0, 0),
#  ('zgLtEob6X-Q', 'please brandon fraiser mummy', 0, 0, 0),
#  ('zgLtEob6X-Q', 'holyshit cruise older than russel crowe', 0, 0, 1),
#  ('zgLtEob6X-Q',
#   'scooby dooby dooooooooooooooooooooooooooooooooooooooooooooooooooo',
#   0,
#   0,
#   0),
#  ('zgLtEob6X-Q', 'https youtube edit video kiau', 0, 0, 0),
#  ('zgLtEob6X-Q', 'lmao they actually uploaded that trailer', 1, 0, 1),
#  ('zgLtEob6X-Q', 'powers suck', 1, 0, 0),
#  ('zgLtEob6X-Q', 'suck', 1, 0, 0),
#  ('zgLtEob6X-Q', 'dummy', 1, 0, 0),
#  ('zgLtEob6X-Q', None, 1, 0, 0),
#  ('zgLtEob6X-Q', None, 1, 0, 0),
#  ('zgLtEob6X-Q', None, 1, 0, 0),
#  ('Ayb_2qbZHm4', 'welcome wage slavery', 16, 1, 1),
#  ('Ayb_2qbZHm4',
#   'raph every year part time degreed student still refers freshmen girls fresh meat',
#   1,
#   0,
#   1),
#  ('Ayb_2qbZHm4',
#   'used live right front tour room mint condition room anyway thing many many parents take opportunity peek even take pictures room when clearly someone room please open peak into other people room even open closed room common leave doors slightly open other dormmates come hang mind hallway push door like creep take picture have problem also know sure that tour guys have warned open doors peak inside because they know parents this many tour guys dormmates',
#   1,
#   0,
#   1),
#  ('Ayb_2qbZHm4',
#   'collegehumor remembered their name made video about college humor been long',
#   1,
#   0,
#   -1),
#  ('Ayb_2qbZHm4',
#   'honestly three weeks into college want kill myself',
#   1,
#   0,
#   1),
#  ('Ayb_2qbZHm4',
#   'have terrified prospect impending future much decisions actually mean despite having years where basically along ride constantly thinks about putting barrel their head',
#   1,
#   0,
#   -1),
#  ('Ayb_2qbZHm4', 'watching this college', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'accepted into hardboard with', 0, 0, 0),
#  ('Ayb_2qbZHm4',
#   'that last with questions literally every time class',
#   0,
#   0,
#   0),
#  ('Ayb_2qbZHm4',
#   'what about construction buildings that actually sound cool will never completed until after finish college',
#   0,
#   0,
#   1),
#  ('Ayb_2qbZHm4',
#   'loud yelly dude blue shirt spot every just want kick those guys right nuts',
#   0,
#   0,
#   1),
#  ('Ayb_2qbZHm4', 'cute throw this garbage', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'forgot mention blue lighting system', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'glad fart never school again', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'last some actual college humor', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'this funny', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'holy shit college joke college humor been while', 0, 0, -1),
#  ('Ayb_2qbZHm4', 'amazon prime student membership just gold', 0, 0, 0),
#  ('Ayb_2qbZHm4',
#   'went boston university when would have spring break would pretend harvard student their classes harvard their lectures were more interesting than ours which totally unfair even gave someone else directions time depressing suffocating though combination people atmosphere only pretended there half',
#   0,
#   0,
#   -1),
#  ('Ayb_2qbZHm4', 'just rekha really cute', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'that', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'real that science buildings hideous', 0, 0, 1),
#  ('Ayb_2qbZHm4',
#   'forgot mention that college complete waste time money people',
#   0,
#   0,
#   -1),
#  ('Ayb_2qbZHm4', 'thank from tour guides everywhere buckeyes', 0, 0, 0),
#  ('Ayb_2qbZHm4',
#   'this collegehumor video actually pretty good even about college',
#   0,
#   0,
#   1),
#  ('Ayb_2qbZHm4', 'that ucla looks super familier', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'holy shit collegehumor video about college', 0, 0, -1),
#  ('Ayb_2qbZHm4', 'actual college based humor', 0, 0, 0),
#  ('Ayb_2qbZHm4',
#   'seems like college season starting anyway dropout rate high',
#   0,
#   0,
#   1),
#  ('Ayb_2qbZHm4', 'well this true have cancer', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'this true', 0, 0, 1),
#  ('Ayb_2qbZHm4',
#   'they should make more violent version this video where statue random black',
#   0,
#   0,
#   -1),
#  ('Ayb_2qbZHm4',
#   'yeah neveryone please watch tiny nature videos there talking them shhh',
#   0,
#   0,
#   0),
#  ('Ayb_2qbZHm4', 'soooo that when took daughter university lolz', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'shit actual college humor video', 0, 0, -1),
#  ('Ayb_2qbZHm4',
#   'forget paying hundreds dollars parking permit being able find parking',
#   0,
#   0,
#   1),
#  ('Ayb_2qbZHm4', 'indian girl', 0, 0, 0),
#  ('Ayb_2qbZHm4',
#   'lmao just went college tour other this pretty spot especially walking backwards jokes students passing going wooooo this place great come here',
#   0,
#   0,
#   1),
#  ('Ayb_2qbZHm4', 'this true many levels that kinda hurts', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'asian classic lolol', 0, 0, 1),
#  ('Ayb_2qbZHm4',
#   'this video sooo racist black only that needs attention that stupid stereo type support your local antifa',
#   0,
#   0,
#   -1),
#  ('Ayb_2qbZHm4',
#   'love idolizing football basketball teams would gladly sell soul support would make university like this',
#   0,
#   0,
#   1),
#  ('Ayb_2qbZHm4', 'think could college would well', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'they being honest here', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'when tour school founded oliver cromwell', 0, 0, 0),
#  ('Ayb_2qbZHm4',
#   'heard evergreen offers best gender studies liberal arts programs today youth',
#   0,
#   0,
#   1),
#  ('Ayb_2qbZHm4',
#   'would like teach some schools special traditions sweet caroline begins play',
#   0,
#   0,
#   1),
#  ('Ayb_2qbZHm4',
#   'after long finally honest video gods have answered prayers',
#   0,
#   0,
#   1),
#  ('Ayb_2qbZHm4', 'katie hair amazing', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'does this kind remind honest movie trailers', 0, 0, 1),
#  ('Ayb_2qbZHm4', None, 0, 0, 0),
#  ('Ayb_2qbZHm4', 'guys honest school please like this they', 0, 0, 1),
#  ('Ayb_2qbZHm4',
#   'well damn basically when introduced career center',
#   0,
#   0,
#   -1),
#  ('Ayb_2qbZHm4', 'make furry force nasty', 0, 0, -1),
#  ('Ayb_2qbZHm4', 'liberal arts school sweetie your', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'college humour makes video about college', 0, 0, 0),
#  ('Ayb_2qbZHm4',
#   'great comedian that gotten millions views thought about suicide thinking about drowning myself many times wanna save please instagram comedian thefreshman they might better than kevin hart',
#   0,
#   0,
#   1),
#  ('Ayb_2qbZHm4',
#   'honest college tour your right place where everyone submits there fake rape accusations slips left bunch disgusting useless borderline retarded straight white male that just looked them already hear them typing typing nazi fascist rapist looks straight ahead antica members destroying trash cans because they wasted there time gender studies leave with your children destroy there minds with ridiculous thoughts then basically tell white ones become slaves would something about straight people afraid that even shit just stabbed beaten with bike lock nthank reading proper script this skit',
#   0,
#   0,
#   -1),
#  ('Ayb_2qbZHm4', 'applying this year this hits close', 0, 0, 0),
#  ('Ayb_2qbZHm4',
#   'college humor sketch revolving around college containing some form humor belated labor miracle',
#   0,
#   0,
#   0),
#  ('Ayb_2qbZHm4', 'cracked basically same thing recently', 0, 0, 0),
#  ('Ayb_2qbZHm4',
#   'been long time collegehumor video with college humor',
#   0,
#   0,
#   -1),
#  ('Ayb_2qbZHm4', 'this accurate', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'head', 0, 0, 0),
#  ('Ayb_2qbZHm4',
#   'ironically these humor videos better reaffirming dislike literally everything than they making actually laugh',
#   0,
#   0,
#   1),
#  ('Ayb_2qbZHm4', 'constantly pointing your jokes funny', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'accuracy hurts', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'this terrifyingly accurate', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'this trending', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'this ucla', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'college university', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'fucking true', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'this fucking hilarious', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'funny true', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'that ucla', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'ayyyyy fellow bruins where', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'brilliant', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'very accurate video', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'whooooo', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'great guys loved', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'spot', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'haha this depressing haha', 0, 0, -1),
#  ('Ayb_2qbZHm4', 'this first', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'polite laughter', 0, 0, 0),
#  ('Ayb_2qbZHm4',
#   'britanick have gotten pudgier more gender diverse lately',
#   0,
#   0,
#   1),
#  ('Ayb_2qbZHm4', 'gotta that sponsorship money', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'most accurate video ever', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'welcome college collge humir', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'cute', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'make funny videos again', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'garbage', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'copied', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'college humour amazing', 0, 0, 1),
#  ('Ayb_2qbZHm4', 'look', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'polite laughter', 0, 0, 0),
#  ('Ayb_2qbZHm4', None, 0, 0, 0),
#  ('Ayb_2qbZHm4', 'generic attention comment', 0, 0, 0),
#  ('Ayb_2qbZHm4', 'zero amount funny', 0, 0, 1),
#  ('Ayb_2qbZHm4',
#   'honest random color hairgender studies lesbian dance theory activist white crowd snowflakes running from safe space safe space scared they might into fact lets real version',
#   0,
#   0,
#   1),
#  ('Ayb_2qbZHm4',
#   'what joke about apply going call woman woman because that offensive those sexually identify attack helicopters trapped womans body',
#   0,
#   0,
#   1),
#  ('CsdzflTXBVQ', 'floyd mayweather swimmer', 3331, 261, 0),
#  ...]

# %%
polarity_scores_DF = Adjusted_polarity.toDF(schema=['video_id', 'comment_text', 'likes', 'replies', 'polarity'])
polarity_scores_DF.createGlobalTempView("polarity_scores_DF")

# %%
polarity_scores_DF.show()
# Out:
# +-----------+--------------------+-----+-------+--------+
# |   video_id|        comment_text|likes|replies|polarity|
# +-----------+--------------------+-----+-------+--------+
# |XpVt6Z1Gjjo|          logan paul|    4|      0|       0|
# |XpVt6Z1Gjjo|been following fr...|    3|      0|       0|
# |XpVt6Z1Gjjo|       kong maverick|    3|      0|       0|
# |XpVt6Z1Gjjo|          attendance|    3|      0|       0|
# |XpVt6Z1Gjjo|            trending|    3|      0|       0|
# |XpVt6Z1Gjjo|   trending ayyeeeee|    3|      0|       0|
# |XpVt6Z1Gjjo|              though|    4|      0|       0|
# |XpVt6Z1Gjjo|            trending|    3|      0|       0|
# |XpVt6Z1Gjjo|happy year vlogav...|    3|      0|       1|
# |XpVt6Z1Gjjo|your shit brother...|    0|      0|      -1|
# |XpVt6Z1Gjjo|there should mini...|    0|      0|       0|
# |XpVt6Z1Gjjo|dear logan really...|    0|      0|       1|
# |XpVt6Z1Gjjo|honestly evan ann...|    0|      0|       1|
# |XpVt6Z1Gjjo|casey still bette...|    0|      0|       1|
# |XpVt6Z1Gjjo|geez rick this fa...|    0|      0|       0|
# |XpVt6Z1Gjjo|   happy cause movie|    0|      0|       1|
# |XpVt6Z1Gjjo|ayyyyoooo logang ...|    1|      0|      -1|
# |XpVt6Z1Gjjo|didnt give merch ...|    0|      0|       0|
# |XpVt6Z1Gjjo|been watching gro...|    3|      0|       1|
# |XpVt6Z1Gjjo|made people hate ...|    0|      0|      -1|
# +-----------+--------------------+-----+-------+--------+
# only showing top 20 rows

# %%
sentimentScores = spark.sql("SELECT video_id, count(case polarity when '1' then 1 else null end) as positive_comments, count(case polarity when '0' then 1 else null end) as neutral_comments, count(case polarity when '-1' then 1 else null end) as negative_comments  FROM global_temp.polarity_scores_DF GROUP BY video_id")
sentimentScores.createGlobalTempView("sentimentScores")

# %%
sentimentScores.show()
# Out:
# +-----------+-----------------+----------------+-----------------+
# |   video_id|positive_comments|neutral_comments|negative_comments|
# +-----------+-----------------+----------------+-----------------+
# |xPS7bqBePSs|              177|             117|                6|
# |dInwVhRtN4E|              171|             330|              198|
# |rn5Xgak1zzA|               67|              69|               64|
# |TzyraAp3jaY|               85|             139|               26|
# |eHq6ZA6uKOg|               63|              71|               37|
# |_r5eTelhpmQ|              160|             114|               15|
# |JkqTeQHFoBY|               64|              50|               20|
# |Bo-qp-Zu0OY|               11|              10|                1|
# |K7pQsR8WFSo|              181|             161|               58|
# |g_ekn1gjBq0|               25|               5|                1|
# |4yCkkOvIkUI|                6|              11|                2|
# |7TN09IP5JuI|              207|             253|               40|
# |RE-far-FvRs|              200|             235|               65|
# |WQjO1mMCPg4|              107|             322|               71|
# |aRgTLb5EbiQ|              337|              51|               12|
# |xNddRhpx5tA|               96|             265|              139|
# |tUXLO8Dtvq4|               47|              83|               70|
# |a7Sf_H2cFdM|              126|             155|               18|
# |mGqR9sgMIyA|                5|              13|                7|
# |fBTBc2OA9fw|               34|              56|               10|
# +-----------+-----------------+----------------+-----------------+
# only showing top 20 rows

# %%
videosDF = spark.read.load('/home/vbhamidipati1/spark/workspace/Project_YouTube_Sentiment_Analysis/Data/USvideos.csv', 
                      format='com.databricks.spark.csv', 
                      header='true', 
                      inferSchema='true')
videosDF.createGlobalTempView("videosDF")

# %%
videosDF.show()
# Out:
# +-----------+--------------------+--------------------+-----------+--------------------+-------+------+--------+-------------+--------------------+-----+
# |   video_id|               title|       channel_title|category_id|                tags|  views| likes|dislikes|comment_total|      thumbnail_link| date|
# +-----------+--------------------+--------------------+-----------+--------------------+-------+------+--------+-------------+--------------------+-----+
# |XpVt6Z1Gjjo|1 YEAR OF VLOGGIN...|    Logan Paul Vlogs|         24|logan paul vlog|l...|4394029|320053|    5931|        46245|https://i.ytimg.c...|13.09|
# |K4wEI5zhHB0|iPhone X — Introd...|               Apple|         28|Apple|iPhone 10|i...|7860119|185853|   26679|            0|https://i.ytimg.c...|13.09|
# |cLdxuaxaQwc|         My Response|           PewDiePie|         22|              [none]|5845909|576597|   39774|       170708|https://i.ytimg.c...|13.09|
# |WYYvHb03Eog|Apple iPhone X fi...|           The Verge|         28|apple iphone x ha...|2642103| 24975|    4542|        12829|https://i.ytimg.c...|13.09|
# |sjlHnJvXdQs|   iPhone X (parody)|          jacksfilms|         23|jacksfilms|parody...|1168130| 96666|     568|         6666|https://i.ytimg.c...|13.09|
# |cMKX2tE5Luk|The Disaster Arti...|                 A24|          1|a24|a24 films|a24...|1311445| 34507|     544|         3040|https://i.ytimg.c...|13.09|
# |8wNr-NQImFg|The Check In: HUD...|Late Night with S...|         23|Late night|Seth M...| 666169|  9985|     297|         1071|https://i.ytimg.c...|13.09|
# |_HTXMhKWqnA|iPhone X Impressi...|    Marques Brownlee|         28|iPhone X|iphone x...|1728614| 74062|    2180|        15297|https://i.ytimg.c...|13.09|
# |_ANP3HR1jsM|ATTACKED BY A POL...|    RomanAtwoodVlogs|         22|Roman Atwood|Roma...|1338533| 69687|     678|         5643|https://i.ytimg.c...|13.09|
# |zgLtEob6X-Q|Honest Trailers -...|      Screen Junkies|          1|screenjunkies|scr...|1056891| 29943|     878|         4046|https://i.ytimg.c...|13.09|
# |Ayb_2qbZHm4| Honest College Tour|        CollegeHumor|         23|Collegehumor|CH o...| 859289| 34485|     726|         1914|https://i.ytimg.c...|13.09|
# |CsdzflTXBVQ|Best Floyd Maywea...|     Awkward Puppets|         23|best floyd maywea...| 452477| 28050|     405|         2745|https://i.ytimg.c...|13.09|
# |l864IBj7cgw|Jennifer Lawrence...|The Tonight Show ...|         23|The Tonight Show|...| 258781|  8085|     303|          726|https://i.ytimg.c...|13.09|
# |4MkC65emkG4|Hand In Hand A Be...|                 MTV|         24|mtv|video|online|...| 274358|  9215|     477|          838|https://i.ytimg.c...|13.09|
# |vu_9muoxT50|Colin Cloud: Mind...|America's Got Talent|         24|America's Got Tal...| 473691| 14740|     415|         1696|https://i.ytimg.c...|13.09|
# |1L7JFN7tQLs|iPhone X Hands on...|   Jonathan Morrison|         28|Apple|iPhone X|iP...| 514972| 18936|     641|         3817|https://i.ytimg.c...|13.09|
# |ZQK1F0wz6z4|What Do You Want ...| Wong Fu Productions|         24|panda|what should...| 282858| 14870|     300|         1398|https://i.ytimg.c...|13.09|
# |T_PuZBdT2iM|getting into a co...|               ProZD|          1|skit|korean|langu...|1582683| 65749|    1531|         3598|https://i.ytimg.c...|13.09|
# |w8fAellnPns|Juicy Chicken Bre...| You Suck At Cooking|         26|how to|cooking|re...| 479951| 23945|     640|         1941|https://i.ytimg.c...|13.09|
# |UCrBICYM0yM|Downsizing (2017)...|  Paramount Pictures|          1|downsizing|previe...|2693468|  7941|     302|         1432|https://i.ytimg.c...|13.09|
# +-----------+--------------------+--------------------+-----------+--------------------+-------+------+--------+-------------+--------------------+-----+
# only showing top 20 rows

# %%
videoScores = spark.sql("SELECT video_id, sum(views) as total_views, sum(likes) as total_likes, sum(dislikes) as total_dislikes FROM global_temp.videosDF GROUP BY video_id")
videoScores.createGlobalTempView("videoScores")
videoScores.show()
# Out:
# +-----------+-----------+-----------+--------------+
# |   video_id|total_views|total_likes|total_dislikes|
# +-----------+-----------+-----------+--------------+
# |xPS7bqBePSs|      76775|       5682|            37|
# |dInwVhRtN4E|   15660374|     392718|         17901|
# |rn5Xgak1zzA|     529514|      40548|           952|
# |TzyraAp3jaY|     228909|       2644|             4|
# |eHq6ZA6uKOg|     135189|       1156|           374|
# |_r5eTelhpmQ|     182342|       7712|           191|
# |JkqTeQHFoBY|     431082|       4694|            43|
# |Bo-qp-Zu0OY|      21654|        179|             1|
# |K7pQsR8WFSo|    2300663|     110553|          1060|
# |g_ekn1gjBq0|      16427|        395|            17|
# |4yCkkOvIkUI|      12905|         59|            43|
# |7TN09IP5JuI|   20785005|     869092|          8855|
# |RE-far-FvRs|    1355210|      63437|          1225|
# |WQjO1mMCPg4|   10417128|     307533|         29960|
# |aRgTLb5EbiQ|      72810|       9292|            48|
# |xNddRhpx5tA|    4393208|     109168|          2060|
# |tUXLO8Dtvq4|     688657|      13542|          1104|
# |a7Sf_H2cFdM|    3823167|     104584|          2979|
# |mGqR9sgMIyA|      25652|         73|            11|
# |fBTBc2OA9fw|     200676|      11690|           328|
# +-----------+-----------+-----------+--------------+
# only showing top 20 rows

# %%
sentimentsJoin = sentimentScores.join(videoScores, sentimentScores.video_id == videoScores.video_id).select(sentimentScores['*'],videoScores['total_views'], videoScores['total_likes'], videoScores['total_dislikes'])
sentimentsJoin.show()
# Out:
# +-----------+-----------------+----------------+-----------------+-----------+-----------+--------------+
# |   video_id|positive_comments|neutral_comments|negative_comments|total_views|total_likes|total_dislikes|
# +-----------+-----------------+----------------+-----------------+-----------+-----------+--------------+
# |xPS7bqBePSs|              177|             117|                6|      76775|       5682|            37|
# |dInwVhRtN4E|              171|             330|              198|   15660374|     392718|         17901|
# |rn5Xgak1zzA|               67|              69|               64|     529514|      40548|           952|
# |TzyraAp3jaY|               85|             139|               26|     228909|       2644|             4|
# |eHq6ZA6uKOg|               63|              71|               37|     135189|       1156|           374|
# |_r5eTelhpmQ|              160|             114|               15|     182342|       7712|           191|
# |JkqTeQHFoBY|               64|              50|               20|     431082|       4694|            43|
# |Bo-qp-Zu0OY|               11|              10|                1|      21654|        179|             1|
# |K7pQsR8WFSo|              181|             161|               58|    2300663|     110553|          1060|
# |g_ekn1gjBq0|               25|               5|                1|      16427|        395|            17|
# |4yCkkOvIkUI|                6|              11|                2|      12905|         59|            43|
# |7TN09IP5JuI|              207|             253|               40|   20785005|     869092|          8855|
# |RE-far-FvRs|              200|             235|               65|    1355210|      63437|          1225|
# |WQjO1mMCPg4|              107|             322|               71|   10417128|     307533|         29960|
# |aRgTLb5EbiQ|              337|              51|               12|      72810|       9292|            48|
# |xNddRhpx5tA|               96|             265|              139|    4393208|     109168|          2060|
# |tUXLO8Dtvq4|               47|              83|               70|     688657|      13542|          1104|
# |a7Sf_H2cFdM|              126|             155|               18|    3823167|     104584|          2979|
# |mGqR9sgMIyA|                5|              13|                7|      25652|         73|            11|
# |fBTBc2OA9fw|               34|              56|               10|     200676|      11690|           328|
# +-----------+-----------------+----------------+-----------------+-----------+-----------+--------------+
# only showing top 20 rows

# %%
sentimentsJoin.repartition(1).write.csv(path="./Data/sentiment_scores")

# %%
spark.stop()
